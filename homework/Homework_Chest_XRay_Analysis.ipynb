# %% [markdown]
# <a href="https://colab.research.google.com/github/maclandrol/cours-ia-med/blob/master/Homework_Chest_XRay_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Devoir 2: Analyse de Radiographies Thoraciques avec l'IA
#
# **Cours:** Informatique et Intelligence Artificielle (IIA2106)
#
# **Enseignant:** Emmanuel Noutahi, PhD
#
# ---
#
# ## Objectifs du Devoir
#
# Ce devoir évalue votre capacité à:
# 1. Utiliser un modèle d'IA pré-entraîné pour analyser des radiographies thoraciques
# 2. Interpréter et visualiser les résultats de manière cliniquement pertinente
# 3. Comparer les prédictions de l'IA avec des diagnostics réels
# 4. Réfléchir de manière critique sur les limites et applications de l'IA médicale
#
# ## Instructions
#
# - **Date limite:** [À définir par l'enseignant]
# - **Format de soumission:** Ce notebook complété (.ipynb) + PDF généré
# - **Travail:** Individuel
# - **Points:** 100 points au total
#
# ## Barème
#
# - **Partie 1 - Configuration et chargement (10 points)**
# - **Partie 2 - Analyse d'images multiples (30 points)**
# - **Partie 3 - Comparaison et évaluation (25 points)**
# - **Partie 4 - Visualisation et rapport (20 points)**
# - **Partie 5 - Réflexion critique (15 points)**
#
# ## Consignes Importantes
#
# 1. **Exécutez toutes les cellules** dans l'ordre
# 2. **Complétez TOUTES les sections** marquées `# VOTRE CODE ICI`
# 3. **Répondez à TOUTES les questions** de réflexion
# 4. **Commentez votre code** pour expliquer votre raisonnement
# 5. **Testez votre code** avant de soumettre

# %% [markdown]
# ---
# ## Partie 1: Configuration et Chargement du Modèle (10 points)
#
# Installez les bibliothèques nécessaires et chargez le modèle TorchXRayVision.

# %%
# Installation des bibliothèques
# !pip install -q torchxrayvision torch torchvision matplotlib numpy pandas pillow scikit-learn

print("Installation terminée!")

# %%
# Importations
import torch
import torchxrayvision as xrv
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import warnings
warnings.filterwarnings('ignore')

# Configuration
plt.rcParams['figure.figsize'] = (14, 8)
device = 'cuda' if torch.cuda.is_available() else 'cpu'

print(f"Dispositif utilisé: {device}")
print(f"PyTorch version: {torch.__version__}")
print(f"TorchXRayVision version: {xrv.__version__}")

# %% [markdown]
# ### Question 1.1 (5 points)
#
# Chargez le modèle DenseNet121 pré-entraîné et affichez la liste des pathologies détectables.

# %%
# VOTRE CODE ICI
# Chargez le modèle avec weights="densenet121-res224-all"
# Déplacez-le sur le device approprié
# Mettez-le en mode évaluation
# Affichez la liste des pathologies

model = None  # À compléter

# Affichage des pathologies
# VOTRE CODE ICI

# %% [markdown]
# ### Question 1.2 (5 points)
#
# Créez une fonction `preparer_image(image_path)` qui:
# 1. Charge une image
# 2. La convertit en niveaux de gris si nécessaire
# 3. La redimensionne à 224x224
# 4. La normalise
# 5. La convertit en tensor PyTorch
# 6. Retourne le tensor prêt pour le modèle

# %%
def preparer_image(image_path):
    """
    Prépare une radiographie pour l'analyse par le modèle.
    
    Paramètres:
        image_path (str): Chemin vers l'image
    
    Retourne:
        torch.Tensor: Image préparée (shape: [1, 1, 224, 224])
    """
    # VOTRE CODE ICI
    
    pass  # Remplacez par votre code

# Test de la fonction (ne modifiez pas cette partie)
# Nous testerons avec une image de test
print("Fonction de préparation créée.")

# %% [markdown]
# ---
# ## Partie 2: Analyse d'Images Multiples (30 points)
#
# Vous allez analyser un ensemble de radiographies thoraciques.

# %% [markdown]
# ### Téléchargement du Dataset
#
# Nous utilisons un petit ensemble de radiographies avec des diagnostics connus.

# %%
# Téléchargement d'images d'exemple
# Pour ce devoir, nous créons un petit dataset de démonstration

import os
os.makedirs('xray_dataset', exist_ok=True)

# URLs d'images d'exemple (radiographies libres de droits)
images_urls = [
    ("https://github.com/ieee8023/covid-chestxray-dataset/raw/master/images/01E392EE-69F9-4E33-BFCE-E5C968654078.jpeg", "patient_001.jpg", "Pneumonia"),
    ("https://github.com/ieee8023/covid-chestxray-dataset/raw/master/images/6C94A287-C059-46A0-8600-AFB95F4727B7.jpeg", "patient_002.jpg", "COVID-19"),
    ("https://github.com/ieee8023/covid-chestxray-dataset/raw/master/images/7C69C793-BFCA-4F0B-96BD-F279092825D9.jpeg", "patient_003.jpg", "Normal"),
]

# Téléchargement
for url, filename, label in images_urls:
    filepath = f"xray_dataset/{filename}"
    if not os.path.exists(filepath):
        # !wget -q {url} -O {filepath}
        print(f"Téléchargé: {filename} (Diagnostic: {label})")

# Création d'un DataFrame avec les métadonnées
dataset_info = pd.DataFrame([
    {"filename": "patient_001.jpg", "diagnostic_reel": "Pneumonia", "age": 45, "sexe": "M"},
    {"filename": "patient_002.jpg", "diagnostic_reel": "COVID-19", "age": 62, "sexe": "F"},
    {"filename": "patient_003.jpg", "diagnostic_reel": "Normal", "age": 28, "sexe": "M"},
])

print("\nDataset créé:")
print(dataset_info)

# %% [markdown]
# ### Question 2.1 (15 points)
#
# Analysez TOUTES les images du dataset et stockez les résultats dans un DataFrame.
#
# Pour chaque image, votre DataFrame doit contenir:
# - Le nom du fichier
# - Les probabilités pour CHAQUE pathologie
# - La pathologie avec la probabilité la plus élevée
# - Cette probabilité maximale

# %%
# VOTRE CODE ICI
# Créez une boucle qui:
# 1. Charge chaque image
# 2. La prépare avec votre fonction preparer_image()
# 3. Fait une prédiction avec le modèle
# 4. Stocke les résultats

resultats = []  # Liste pour stocker les résultats

for idx, row in dataset_info.iterrows():
    filename = row['filename']
    filepath = f"xray_dataset/{filename}"
    
    # VOTRE CODE ICI
    # Préparez l'image
    # Faites la prédiction
    # Stockez les résultats
    
    pass  # Remplacez par votre code

# Conversion en DataFrame
resultats_df = pd.DataFrame(resultats)

# Affichage
print("Résultats de l'analyse:")
print(resultats_df.head())

# %% [markdown]
# ### Question 2.2 (10 points)
#
# Pour CHAQUE image, créez une visualisation qui montre:
# 1. L'image originale
# 2. Un graphique à barres des top 5 pathologies détectées
# 3. Le diagnostic réel (si disponible)

# %%
# VOTRE CODE ICI
# Pour chaque image du dataset:
# - Créez une figure avec 2 subplots (1 ligne, 2 colonnes)
# - Subplot 1: Image originale
# - Subplot 2: Barres horizontales des top 5 pathologies

for idx, row in dataset_info.iterrows():
    filename = row['filename']
    diagnostic_reel = row['diagnostic_reel']
    
    # VOTRE CODE ICI
    
    pass  # Remplacez par votre code

# %% [markdown]
# ### Question 2.3 (5 points)
#
# Créez un tableau récapitulatif qui montre, pour chaque patient:
# - Nom du fichier
# - Diagnostic réel
# - Top 3 prédictions de l'IA (avec probabilités)
# - Votre interprétation: l'IA a-t-elle détecté la bonne pathologie?

# %%
# VOTRE CODE ICI
# Créez un DataFrame récapitulatif

recapitulatif = []  # À compléter

# VOTRE CODE ICI

recapitulatif_df = pd.DataFrame(recapitulatif)
print(recapitulatif_df)

# %% [markdown]
# ---
# ## Partie 3: Comparaison et Évaluation (25 points)
#
# Maintenant, nous allons comparer les prédictions de l'IA avec les diagnostics réels.

# %% [markdown]
# ### Question 3.1 (10 points)
#
# Pour évaluer la performance de l'IA, nous devons définir quand une prédiction est "correcte".
#
# Créez une fonction `evaluer_prediction(pathologie_predite, pathologie_reelle, seuil)` qui:
# - Retourne True si la prédiction contient la pathologie réelle
# - Gère les cas spéciaux (ex: "Pneumonia" vs "Bacterial Pneumonia")
# - Utilise un seuil de probabilité

# %%
def evaluer_prediction(top_pathologies, pathologie_reelle, seuil=0.3):
    """
    Évalue si la prédiction de l'IA est correcte.
    
    Paramètres:
        top_pathologies (list): Liste de tuples (pathologie, probabilité)
        pathologie_reelle (str): Diagnostic réel
        seuil (float): Seuil de probabilité minimum
    
    Retourne:
        bool: True si la prédiction est considérée correcte
    """
    # VOTRE CODE ICI
    
    pass  # Remplacez par votre code

# Test de la fonction
test_preds = [("Pneumonia", 0.8), ("Edema", 0.3)]
print(f"Test 1: {evaluer_prediction(test_preds, 'Pneumonia', 0.3)}")
print(f"Test 2: {evaluer_prediction(test_preds, 'Normal', 0.3)}")

# %% [markdown]
# ### Question 3.2 (10 points)
#
# Calculez les métriques de performance suivantes pour votre modèle:
#
# 1. **Taux de détection**: Pourcentage de cas où l'IA a identifié la pathologie réelle
# 2. **Probabilité moyenne** pour les vraies pathologies
# 3. **Rang moyen** de la vraie pathologie dans les prédictions
#
# Testez avec différents seuils: 0.3, 0.5, 0.7

# %%
# VOTRE CODE ICI
# Calculez les métriques pour différents seuils

seuils = [0.3, 0.5, 0.7]
metriques = []

for seuil in seuils:
    # VOTRE CODE ICI
    # Calculez:
    # - Taux de détection
    # - Probabilité moyenne
    # - Rang moyen
    
    pass  # Remplacez par votre code

# Affichage sous forme de tableau
metriques_df = pd.DataFrame(metriques)
print("\nPerformance selon le seuil:")
print(metriques_df)

# %% [markdown]
# ### Question 3.3 (5 points)
#
# Identifiez les cas où l'IA a échoué (faux négatifs) et analysez pourquoi.
#
# Pour chaque échec, proposez une hypothèse sur la cause (qualité d'image, pathologie rare, etc.)

# %%
# VOTRE CODE ICI
# Identifiez et analysez les échecs

print("Analyse des échecs:")
# VOTRE CODE ET ANALYSE ICI

# %% [markdown]
# ---
# ## Partie 4: Visualisation et Rapport (20 points)
#
# Créez des visualisations professionnelles pour communiquer vos résultats.

# %% [markdown]
# ### Question 4.1 (10 points)
#
# Créez un dashboard de résumé avec 4 visualisations:
#
# 1. **Distribution des probabilités** pour toutes les pathologies
# 2. **Comparaison diagnostic réel vs IA** (graphique à barres)
# 3. **Heatmap des probabilités** (patients × pathologies)
# 4. **Performance selon le seuil** (courbe)

# %%
# VOTRE CODE ICI
# Créez une figure avec 4 subplots (2x2)

fig, axes = plt.subplots(2, 2, figsize=(16, 12))

# Subplot 1: Distribution des probabilités
# VOTRE CODE ICI

# Subplot 2: Comparaison réel vs IA
# VOTRE CODE ICI

# Subplot 3: Heatmap
# VOTRE CODE ICI

# Subplot 4: Performance vs seuil
# VOTRE CODE ICI

plt.tight_layout()
plt.savefig('dashboard_resultats.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Question 4.2 (10 points)
#
# Rédigez un rapport clinique professionnel (format texte) qui inclut:
#
# 1. **Résumé exécutif** (3-4 phrases)
# 2. **Méthodologie** (modèle utilisé, dataset)
# 3. **Résultats principaux** (métriques, observations)
# 4. **Cas intéressants** (succès et échecs)
# 5. **Recommandations** pour l'utilisation clinique

# %% [markdown]
# ### VOTRE RAPPORT ICI
#
# #### Résumé Exécutif
# [Votre texte ici]
#
# #### Méthodologie
# [Votre texte ici]
#
# #### Résultats Principaux
# [Votre texte ici]
#
# #### Cas Intéressants
# [Votre texte ici]
#
# #### Recommandations
# [Votre texte ici]

# %% [markdown]
# ---
# ## Partie 5: Réflexion Critique (15 points)
#
# Répondez aux questions suivantes de manière réfléchie et argumentée.

# %% [markdown]
# ### Question 5.1 (5 points)
#
# **Biais et Limitations:**
#
# Le modèle TorchXRayVision a été entraîné principalement sur des données de patients américains et européens.
#
# a) Quels biais potentiels cela pourrait-il introduire?
#
# b) Comment cela pourrait-il affecter la performance dans d'autres contextes (Afrique, Asie)?
#
# c) Que faudrait-il faire avant de déployer ce modèle dans un hôpital en Haïti?

# %% [markdown]
# **Votre réponse ici:**
#
# a) [Votre réponse]
#
# b) [Votre réponse]
#
# c) [Votre réponse]

# %% [markdown]
# ### Question 5.2 (5 points)
#
# **Seuil de Décision:**
#
# Vous avez testé différents seuils (0.3, 0.5, 0.7) pour déterminer si une pathologie est "détectée".
#
# a) Quel seuil recommanderiez-vous pour un service d'urgence? Justifiez.
#
# b) Quel seuil pour un dépistage de masse? Justifiez.
#
# c) Expliquez le compromis entre faux positifs et faux négatifs dans chaque contexte.

# %% [markdown]
# **Votre réponse ici:**
#
# a) [Votre réponse]
#
# b) [Votre réponse]
#
# c) [Votre réponse]

# %% [markdown]
# ### Question 5.3 (5 points)
#
# **Responsabilité et Éthique:**
#
# Imaginez le scénario suivant:
#
# > Un patient de 55 ans arrive aux urgences avec douleurs thoraciques. La radiographie est analysée par l'IA qui indique "Pneumonia: 25%, Normal: 75%". Le médecin urgentiste, débordé, fait confiance au "Normal" et renvoie le patient chez lui. Le lendemain, le patient revient en détresse respiratoire sévère avec une pneumonie confirmée.
#
# a) Qui est responsable de cette erreur?
#
# b) Quelle erreur a été commise dans l'utilisation de l'IA?
#
# c) Comment ce type de situation pourrait-il être évité?

# %% [markdown]
# **Votre réponse ici:**
#
# a) [Votre réponse]
#
# b) [Votre réponse]
#
# c) [Votre réponse]

# %% [markdown]
# ---
# ## Soumission
#
# Avant de soumettre, vérifiez que:
#
# - [ ] Toutes les cellules de code ont été exécutées
# - [ ] Tous les graphiques s'affichent correctement
# - [ ] Toutes les questions ont reçu une réponse
# - [ ] Le code est commenté
# - [ ] Le rapport est rédigé de manière professionnelle
# - [ ] Les réflexions critiques sont argumentées
#
# **Fichiers à soumettre:**
# 1. Ce notebook complété (.ipynb)
# 2. Version PDF du notebook
# 3. L'image dashboard_resultats.png
#
# **Bonne chance!**
